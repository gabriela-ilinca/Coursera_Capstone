# %%
from PIL import Image
import requests
url = 'https://www.centurycommunities.com/Images/ImageManager/States/Georgia_2/SizedBanner/Atlanta%20(2)_1920x715.jpg'
im = Image.open(requests.get(url, stream=True).raw)
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x715 at 0x7FE154C71F28>

# %% [markdown]
# ### Introduction to the Problem

# %% [markdown]
# People from all over America are beginning to flock to Atlanta, Georgia. In the last year, it became the 4th fastest growing city in the US. With varying budgets and needs, people find it very hard to find affordable housing to accommodate them and their families. Due to the high cost of living and other issues, Atlanta housing has been struggling. With the explosive population growth, the problem has only increased.
#
# As the city grows and develops, it becomes increasingly important to examine and understand it quantitiatively.
#
# A potential homeowner, developer, or city planner may have an interest in answering the following questions:
#
#     1. What neighbourhoods have the highest crime?
#     2. Is population density correlated to crime level?
#     3. Using Foursquare data, what venues are most common in different locations within the city?
#     4. What neighborhood has the closest proximity to schools, medical care, and restaurants?

# %% [markdown]
# ### Data

# %% [markdown]
# OpenData Site:http://data-georgiagio.opendata.arcgis.com/
# Neighbourhoods: https://neighborhoodnexus.org/case-studies/coa/#Dashboard
# Crime: http://opendata.atlantapd.org/Crimedata/Default.aspx
# Atlanta Demographics: https://neighborhoodnexus.org/case-studies/coa/#Dashboard
# Atlanta Census:
# Atlanta Commute: https://neighborhoodnexus.org/case-studies/coa/#Dashboard
# Foursquare developer: https://foursquare.com/developers/apps
#
#
# Using this data will allow exploration and examination to answer the questions. The neighbourhood data will enable us to properly group crime by neighbourhood. The Census data will enable us to then compare the population density to examine if areas of highest crime are also most densely populated. Fredericton locations of interest will then allow us to cluster and quantitatively understand the venues most common to that location.
